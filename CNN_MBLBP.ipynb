# %%
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dense, Dropout, Lambda, Flatten, Conv2D, BatchNormalization, Activation, MaxPooling2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.datasets import mnist
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import seaborn as sns
import numpy as np
import pandas as pd
import PIL
from PIL import Image
import cv2
import os
import matplotlib.pyplot as plt
# Out:
# 2023-04-04 16:06:48.811838: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
train=pd.read_csv('/Users/khushm/Documents/GitHub/MINIPROJECT_CNNLBP/train.csv')
test=pd.read_csv('/Users/khushm/Documents/GitHub/MINIPROJECT_CNNLBP/test.csv')
sub=pd.read_csv('/Users/khushm/Documents/GitHub/MINIPROJECT_CNNLBP/output.csv')
emotions = ('happy', 'sad','fearful','neutral','angry','disgusted','surprised')

# %%
print(f"Training data size {train.shape}\nTesting data size {test.shape}")
# Out:
# Training data size (28709, 577)
# Testing data size (7178, 576)

# %%
X = train.drop(['Labels'], 1).values
y = train['Labels'].values
X = X / 255.0
X = X.reshape(-1,24,24,1) #reshaping the image to 3 dimensions, canal=1 for grayscale
y = to_categorical(y) #Encoding labels to one hot vector 
print(f"Label size {y.shape}")
# Out:
# Label size (28709, 7)
# /var/folders/m5/g2s2vm2d69s8qfj5cc66mryw0000gn/T/ipykernel_34514/2809775689.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   X = train.drop(['Labels'], 1).values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=0)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((25838, 24, 24, 1), (2871, 24, 24, 1), (25838, 7), (2871, 7))

# %%
X_train__ = X_train.reshape(X_train.shape[0], 24, 24)
fig, axis = plt.subplots(1, 4, figsize=(20, 10))
for i, ax in enumerate(axis.flat):
    ax.imshow(X_train__[i], cmap='binary')
    digit = y_train[i].argmax()
    ax.set(title = f"Real emotion is {emotions[digit]}"); #Data visualisation

# %%
mean = np.mean(X_train)
std = np.std(X_train)

def standardize(x):
    return (x-mean)/std #Normalisation

# %%
#Defining the CNN model

model=Sequential()
   
model.add(Conv2D(filters=64, kernel_size = (3,3), activation="relu", input_shape=(24,24,1)))
model.add(Conv2D(filters=64, kernel_size = (3,3), activation="relu"))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())

model.add(Conv2D(filters=128, kernel_size = (3,3), activation="relu"))
model.add(Conv2D(filters=128, kernel_size = (3,3), activation="relu"))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())    

model.add(Conv2D(filters=256, kernel_size = (3,3), activation="relu"))
# model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())
    
model.add(Flatten())
model.add(Dense(512,activation="relu"))
    
model.add(Dense(7,activation="softmax"))
    
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_17 (Conv2D)          (None, 22, 22, 64)        640
#
#  conv2d_18 (Conv2D)          (None, 20, 20, 64)        36928
#
#  max_pooling2d_9 (MaxPooling  (None, 10, 10, 64)       0
#  2D)
#
#  batch_normalization_8 (Batc  (None, 10, 10, 64)       256
#  hNormalization)
#
#  conv2d_19 (Conv2D)          (None, 8, 8, 128)         73856
#
#  conv2d_20 (Conv2D)          (None, 6, 6, 128)         147584
#
#  max_pooling2d_10 (MaxPoolin  (None, 3, 3, 128)        0
#  g2D)
#
#  batch_normalization_9 (Batc  (None, 3, 3, 128)        512
#  hNormalization)
#
#  conv2d_21 (Conv2D)          (None, 1, 1, 256)         295168
#
#  batch_normalization_10 (Bat  (None, 1, 1, 256)        1024
#  chNormalization)
#
#  flatten_3 (Flatten)         (None, 256)               0
#
#  dense_6 (Dense)             (None, 512)               131584
#
#  dense_7 (Dense)             (None, 7)                 3591
#
# =================================================================
# Total params: 691,143
# Trainable params: 690,247
# Non-trainable params: 896
# _________________________________________________________________

# %%
# With data augmentation to prevent overfitting

datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=15,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.01, # Randomly zoom image 
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=False,  # randomly flip images
        vertical_flip=False)  # randomly flip images


#datagen.fit(X_train)
train_gen = datagen.flow(X_train, y_train, batch_size=120)
test_gen = datagen.flow(X_test, y_test, batch_size=120)

# %%
epochs = 50
batch_size = 120
train_steps = X_train.shape[0] // batch_size
valid_steps = X_test.shape[0] // batch_size

es = tf.keras.callbacks.EarlyStopping(
        monitor="val_accuracy", # metrics to monitor
        patience=10, # how many epochs before stop
        verbose=1,
        mode="max", # we need the maximum accuracy.
        restore_best_weights=True, # 
     )

rp = tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_accuracy",
        factor=0.2,
        patience=3,
        verbose=1,
        mode="max",
        min_lr=0.00001,
     )

# %%
# Fit the model
history = model.fit(train_gen, 
                              epochs = epochs, 
                              steps_per_epoch = train_steps,
                              validation_data = test_gen,
                              validation_steps = valid_steps, 
                              callbacks=[es, rp])
# Out:
# Epoch 1/50
# 215/215 [==============================] - 70s 321ms/step - loss: 1.7390 - accuracy: 0.3186 - val_loss: 2.2424 - val_accuracy: 0.1319 - lr: 0.0010
# Epoch 2/50
# 215/215 [==============================] - 66s 307ms/step - loss: 1.5889 - accuracy: 0.3799 - val_loss: 1.7419 - val_accuracy: 0.2877 - lr: 0.0010
# Epoch 3/50
# 215/215 [==============================] - 65s 303ms/step - loss: 1.5143 - accuracy: 0.4092 - val_loss: 1.6023 - val_accuracy: 0.3558 - lr: 0.0010
# Epoch 19: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 215/215 [==============================] - 65s 301ms/step - loss: 1.0777 - accuracy: 0.5874 - val_loss: 1.3342 - val_accuracy: 0.5025 - lr: 2.0000e-04
# Epoch 20/50
# 215/215 [==============================] - 65s 301ms/step - loss: 1.0563 - accuracy: 0.6004 - val_loss: 1.3071 - val_accuracy: 0.4996 - lr: 4.0000e-05
# Epoch 21/50
# 215/215 [==============================] - 67s 312ms/step - loss: 1.0527 - accuracy: 0.6024 - val_loss: 1.2867 - val_accuracy: 0.5199 - lr: 4.0000e-05
# Epoch 22/50
# 215/215 [==============================] - 70s 326ms/step - loss: 1.0492 - accuracy: 0.6044 - val_loss: 1.3011 - val_accuracy: 0.5178 - lr: 4.0000e-05
# Epoch 23/50
# 215/215 [==============================] - 70s 328ms/step - loss: 1.0412 - accuracy: 0.6082 - val_loss: 1.3047 - val_accuracy: 0.5174 - lr: 4.0000e-05
# Epoch 24/50
# 215/215 [==============================] - ETA: 0s - loss: 1.0334 - accuracy: 0.6097
# Epoch 24: ReduceLROnPlateau reducing learning rate to 1e-05.
# 215/215 [==============================] - 71s 330ms/step - loss: 1.0334 - accuracy: 0.6097 - val_loss: 1.3031 - val_accuracy: 0.5188 - lr: 4.0000e-05
# Epoch 25/50
# 215/215 [==============================] - 74s 344ms/step - loss: 1.0355 - accuracy: 0.6081 - val_loss: 1.3043 - val_accuracy: 0.5072 - lr: 1.0000e-05
# Epoch 26/50
# 215/215 [==============================] - 77s 358ms/step - loss: 1.0365 - accuracy: 0.6121 - val_loss: 1.2965 - val_accuracy: 0.5221 - lr: 1.0000e-05
# Epoch 27/50
# 215/215 [==============================] - 71s 330ms/step - loss: 1.0278 - accuracy: 0.6157 - val_loss: 1.2983 - val_accuracy: 0.5185 - lr: 1.0000e-05
# Epoch 28/50
# 215/215 [==============================] - 70s 328ms/step - loss: 1.0292 - accuracy: 0.6149 - val_loss: 1.2897 - val_accuracy: 0.5257 - lr: 1.0000e-05
# Epoch 29/50
# 215/215 [==============================] - 70s 326ms/step - loss: 1.0290 - accuracy: 0.6137 - val_loss: 1.3015 - val_accuracy: 0.5210 - lr: 1.0000e-05
# Epoch 30/50
# 215/215 [==============================] - 70s 326ms/step - loss: 1.0248 - accuracy: 0.6202 - val_loss: 1.2910 - val_accuracy: 0.5174 - lr: 1.0000e-05
# Epoch 31/50
# 215/215 [==============================] - 73s 340ms/step - loss: 1.0270 - accuracy: 0.6148 - val_loss: 1.2964 - val_accuracy: 0.5257 - lr: 1.0000e-05
# Epoch 32/50
# 215/215 [==============================] - 85s 395ms/step - loss: 1.0259 - accuracy: 0.6138 - val_loss: 1.2979 - val_accuracy: 0.5116 - lr: 1.0000e-05
# Epoch 33/50
# 215/215 [==============================] - 73s 342ms/step - loss: 1.0253 - accuracy: 0.6118 - val_loss: 1.3020 - val_accuracy: 0.5101 - lr: 1.0000e-05
# Epoch 34/50
# 215/215 [==============================] - 73s 338ms/step - loss: 1.0185 - accuracy: 0.6209 - val_loss: 1.2822 - val_accuracy: 0.5322 - lr: 1.0000e-05
# Epoch 35/50
# 215/215 [==============================] - 73s 341ms/step - loss: 1.0184 - accuracy: 0.6136 - val_loss: 1.2880 - val_accuracy: 0.5159 - lr: 1.0000e-05
# Epoch 36/50
# 215/215 [==============================] - 72s 337ms/step - loss: 1.0183 - accuracy: 0.6147 - val_loss: 1.2728 - val_accuracy: 0.5268 - lr: 1.0000e-05
# Epoch 37/50
# 215/215 [==============================] - 73s 338ms/step - loss: 1.0227 - accuracy: 0.6181 - val_loss: 1.2960 - val_accuracy: 0.5149 - lr: 1.0000e-05
# Epoch 38/50
# 215/215 [==============================] - 72s 334ms/step - loss: 1.0177 - accuracy: 0.6166 - val_loss: 1.2887 - val_accuracy: 0.5207 - lr: 1.0000e-05
# Epoch 39/50
# 215/215 [==============================] - 71s 329ms/step - loss: 1.0170 - accuracy: 0.6185 - val_loss: 1.3082 - val_accuracy: 0.5174 - lr: 1.0000e-05
# Epoch 40/50
# 215/215 [==============================] - 70s 328ms/step - loss: 1.0234 - accuracy: 0.6132 - val_loss: 1.2918 - val_accuracy: 0.5214 - lr: 1.0000e-05
# Epoch 41/50
# 215/215 [==============================] - 73s 340ms/step - loss: 1.0214 - accuracy: 0.6157 - val_loss: 1.2799 - val_accuracy: 0.5243 - lr: 1.0000e-05
# Epoch 42/50
# 215/215 [==============================] - 75s 348ms/step - loss: 1.0180 - accuracy: 0.6161 - val_loss: 1.2894 - val_accuracy: 0.5228 - lr: 1.0000e-05
# Epoch 43/50
# 215/215 [==============================] - 66s 308ms/step - loss: 1.0152 - accuracy: 0.6215 - val_loss: 1.2979 - val_accuracy: 0.5134 - lr: 1.0000e-05
# Epoch 44/50
# 215/215 [==============================] - ETA: 0s - loss: 1.0145 - accuracy: 0.6155Restoring model weights from the end of the best epoch: 34.
# 215/215 [==============================] - 66s 308ms/step - loss: 1.0145 - accuracy: 0.6155 - val_loss: 1.3095 - val_accuracy: 0.5094 - lr: 1.0000e-05
# Epoch 44: early stopping

# %%
# Plot the loss and accuracy curves for training and validation 
fig, ax = plt.subplots(2,1, figsize=(18, 10))
ax[0].plot(history.history['loss'], color='b', label="Training loss")
ax[0].plot(history.history['val_loss'], color='r', label="validation loss",axes =ax[0])
legend = ax[0].legend(loc='best', shadow=True)

ax[1].plot(history.history['accuracy'], color='b', label="Training accuracy")
ax[1].plot(history.history['val_accuracy'], color='r',label="Validation accuracy")
legend = ax[1].legend(loc='best', shadow=True)

# %%
fig = plt.figure(figsize=(14, 18)) # Set Figure

y_pred = model.predict(X_test) # Predict class probabilities as 2 => [0.1, 0, 0.9, 0, 0, 0, 0, 0, 0, 0]

Y_pred = np.argmax(y_pred, 1) # Decode Predicted labels
Y_test = np.argmax(y_test, 1) # Decode labels
print(y_test.shape)

mat = confusion_matrix(Y_test, Y_pred) # Confusion matrix

#Plot Confusion matrix
sns.heatmap(mat.T, square=True, annot=True, cbar=False, cmap=plt.cm.Blues, fmt='.0f')
plt.xlabel('Predicted Values')
plt.ylabel('True Values');
plt.show();
# Out:
# 90/90 [==============================] - 2s 26ms/step
# (2871, 7)

# %%
y_pred = model.predict(X_test)
X_test__ = X_test.reshape(X_test.shape[0], 24, 24)

fig, axis = plt.subplots(4, 4, figsize=(12, 14))
fig.tight_layout(pad=3.0)
for i, ax in enumerate(axis.flat):
    ax.imshow(X_test__[i], cmap='binary')
    ax.set(title = f"Real emotion class {emotions[y_test[i].argmax()]}\nPredicted emotion class {emotions[y_pred[i].argmax()]}");
# Out:
# 90/90 [==============================] - 2s 26ms/step
