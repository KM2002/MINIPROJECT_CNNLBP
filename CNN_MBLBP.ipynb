# %%
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dense, Dropout, Lambda, Flatten, Conv2D, BatchNormalization, Activation, MaxPooling2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.datasets import mnist
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import seaborn as sns
import numpy as np
import pandas as pd
import PIL
from PIL import Image
import cv2
import os
import matplotlib.pyplot as plt
# Out:
# 2023-04-26 11:44:36.302275: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
train=pd.read_csv('/Users/khushm/Documents/GitHub/MINIPROJECT_CNNLBP/training.csv')
test=pd.read_csv('/Users/khushm/Documents/GitHub/MINIPROJECT_CNNLBP/testing.csv')
sub=pd.read_csv('/Users/khushm/Documents/GitHub/MINIPROJECT_CNNLBP/output.csv')
emotions = ('happy', 'sad','fearful','neutral','angry','disgusted','surprised')

# %%
print(f"Training data size {train.shape}\nTesting data size {test.shape}")
# Out:
# Training data size (28709, 65)
# Testing data size (7178, 64)

# %%
X = train.drop(['Labels'], 1).values
y = train['Labels'].values
X = X / 255.0
X = X.reshape(-1,8,8,1) #reshaping the image to 3 dimensions, canal=1 for grayscale
y = to_categorical(y) #Encoding labels to one hot vector 
print(f"Label size {y.shape}")
# Out:
# Label size (28709, 7)
# /var/folders/m5/g2s2vm2d69s8qfj5cc66mryw0000gn/T/ipykernel_14743/610811677.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   X = train.drop(['Labels'], 1).values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=0)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((25838, 8, 8, 1), (2871, 8, 8, 1), (25838, 7), (2871, 7))

# %%
X_train__ = X_train.reshape(X_train.shape[0], 8, 8)
fig, axis = plt.subplots(1, 4, figsize=(20, 10))
for i, ax in enumerate(axis.flat):
    ax.imshow(X_train__[i], cmap='binary')
    digit = y_train[i].argmax()
    ax.set(title = f"Real emotion is {emotions[digit]}"); #Data visualisation

# %%
mean = np.mean(X_train)
std = np.std(X_train)

def standardize(x):
    return (x-mean)/std #Normalisation

# %%
#Defining the CNN model

model = Sequential()
   
model.add(Conv2D(filters=32, kernel_size=(2, 2), activation="relu", input_shape=(8, 8, 1)))
model.add(Conv2D(filters=32, kernel_size=(2, 2), activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization())

model.add(Conv2D(filters=32, kernel_size=(3, 3), activation="relu"))
#model.add(Conv2D(filters=64, kernel_size=(3, 3), activation="relu"))
#model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization())    

# model.add(Conv2D(filters=128, kernel_size=(4, 4), activation="relu"))
# model.add(Conv2D(filters=128, kernel_size=(4, 4), activation="relu"))
# model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization())
    
model.add(Flatten())
model.add(Dense(128, activation="relu"))
    
model.add(Dense(7, activation="softmax"))
    
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 7, 7, 32)          160
#
#  conv2d_1 (Conv2D)           (None, 6, 6, 32)          4128
#
#  max_pooling2d (MaxPooling2D  (None, 3, 3, 32)         0
#  )
#
#  batch_normalization (BatchN  (None, 3, 3, 32)         128
#  ormalization)
#
#  conv2d_2 (Conv2D)           (None, 1, 1, 32)          9248
#
#  batch_normalization_1 (Batc  (None, 1, 1, 32)         128
#  hNormalization)
#
#  batch_normalization_2 (Batc  (None, 1, 1, 32)         128
#  hNormalization)
#
#  flatten (Flatten)           (None, 32)                0
#
#  dense (Dense)               (None, 128)               4224
#
#  dense_1 (Dense)             (None, 7)                 903
#
# =================================================================
# Total params: 19,047
# Trainable params: 18,855
# Non-trainable params: 192
# _________________________________________________________________
# 2023-04-26 11:44:42.203161: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# With data augmentation to prevent overfitting

datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=15,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.01, # Randomly zoom image 
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=False,  # randomly flip images
        vertical_flip=False)  # randomly flip images


#datagen.fit(X_train)
train_gen = datagen.flow(X_train, y_train, batch_size=120)
test_gen = datagen.flow(X_test, y_test, batch_size=120)

# %%
epochs = 50
batch_size = 120
train_steps = X_train.shape[0] // batch_size
valid_steps = X_test.shape[0] // batch_size

es = tf.keras.callbacks.EarlyStopping(
        monitor="val_accuracy", # metrics to monitor
        patience=10, # how many epochs before stop
        verbose=1,
        mode="max", # we need the maximum accuracy.
        restore_best_weights=True, # 
     )

rp = tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_accuracy",
        factor=0.2,
        patience=3,
        verbose=1,
        mode="max",
        min_lr=0.00001,
     )

# %%
# Fit the model
history = model.fit(train_gen, 
                              epochs = epochs, 
                              steps_per_epoch = train_steps,
                              validation_data = test_gen,
                              validation_steps = valid_steps, 
                              callbacks=[es, rp])
# Out:
# Epoch 1/50
# 215/215 [==============================] - 6s 24ms/step - loss: 1.8351 - accuracy: 0.2388 - val_loss: 1.8502 - val_accuracy: 0.2471 - lr: 0.0010
# Epoch 2/50
# 215/215 [==============================] - 5s 23ms/step - loss: 1.8010 - accuracy: 0.2515 - val_loss: 1.8533 - val_accuracy: 0.1804 - lr: 0.0010
# Epoch 3/50
# 215/215 [==============================] - 5s 25ms/step - loss: 1.7955 - accuracy: 0.2537 - val_loss: 1.8265 - val_accuracy: 0.2217 - lr: 0.0010
# Epoch 4/50
# 215/215 [==============================] - 5s 24ms/step - loss: 1.7909 - accuracy: 0.2587 - val_loss: 1.8039 - val_accuracy: 0.2525 - lr: 0.0010
# Epoch 5/50
# 215/215 [==============================] - 5s 25ms/step - loss: 1.7871 - accuracy: 0.2613 - val_loss: 1.7884 - val_accuracy: 0.2641 - lr: 0.0010
# Epoch 6/50
# 215/215 [==============================] - 6s 26ms/step - loss: 1.7830 - accuracy: 0.2630 - val_loss: 1.8189 - val_accuracy: 0.2594 - lr: 0.0010
# Epoch 7/50
# 215/215 [==============================] - 5s 24ms/step - loss: 1.7825 - accuracy: 0.2642 - val_loss: 1.8021 - val_accuracy: 0.2638 - lr: 0.0010
# Epoch 8/50
# 214/215 [============================>.] - ETA: 0s - loss: 1.7786 - accuracy: 0.2659
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 215/215 [==============================] - 5s 23ms/step - loss: 1.7786 - accuracy: 0.2659 - val_loss: 1.8418 - val_accuracy: 0.2196 - lr: 0.0010
# Epoch 9/50
# 215/215 [==============================] - 5s 25ms/step - loss: 1.7753 - accuracy: 0.2682 - val_loss: 1.7876 - val_accuracy: 0.2692 - lr: 2.0000e-04
# Epoch 10/50
# 215/215 [==============================] - 5s 23ms/step - loss: 1.7724 - accuracy: 0.2687 - val_loss: 1.7846 - val_accuracy: 0.2627 - lr: 2.0000e-04
# Epoch 11/50
# 215/215 [==============================] - 5s 23ms/step - loss: 1.7731 - accuracy: 0.2684 - val_loss: 1.7890 - val_accuracy: 0.2536 - lr: 2.0000e-04
# Epoch 12/50
# 215/215 [==============================] - 5s 23ms/step - loss: 1.7709 - accuracy: 0.2707 - val_loss: 1.7714 - val_accuracy: 0.2739 - lr: 2.0000e-04
# Epoch 13/50
# 215/215 [==============================] - 5s 25ms/step - loss: 1.7704 - accuracy: 0.2685 - val_loss: 1.7792 - val_accuracy: 0.2663 - lr: 2.0000e-04
# Epoch 14/50
# 215/215 [==============================] - 5s 24ms/step - loss: 1.7683 - accuracy: 0.2730 - val_loss: 1.7850 - val_accuracy: 0.2772 - lr: 2.0000e-04
# Epoch 15/50
# 215/215 [==============================] - 5s 23ms/step - loss: 1.7699 - accuracy: 0.2695 - val_loss: 1.7773 - val_accuracy: 0.2732 - lr: 2.0000e-04
# Epoch 16/50
# 215/215 [==============================] - 5s 23ms/step - loss: 1.7681 - accuracy: 0.2709 - val_loss: 1.7753 - val_accuracy: 0.2612 - lr: 2.0000e-04
# Epoch 17/50
# 213/215 [============================>.] - ETA: 0s - loss: 1.7686 - accuracy: 0.2718
# Epoch 17: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 215/215 [==============================] - 5s 23ms/step - loss: 1.7680 - accuracy: 0.2719 - val_loss: 1.7887 - val_accuracy: 0.2699 - lr: 2.0000e-04
# Epoch 18/50
# 215/215 [==============================] - 5s 23ms/step - loss: 1.7669 - accuracy: 0.2714 - val_loss: 1.7746 - val_accuracy: 0.2612 - lr: 4.0000e-05
# Epoch 19/50
# 215/215 [==============================] - 5s 23ms/step - loss: 1.7674 - accuracy: 0.2716 - val_loss: 1.7755 - val_accuracy: 0.2779 - lr: 4.0000e-05
# Epoch 20/50
# 215/215 [==============================] - 5s 25ms/step - loss: 1.7659 - accuracy: 0.2727 - val_loss: 1.7653 - val_accuracy: 0.2743 - lr: 4.0000e-05
# Epoch 21/50
# 215/215 [==============================] - 5s 23ms/step - loss: 1.7658 - accuracy: 0.2737 - val_loss: 1.7715 - val_accuracy: 0.2783 - lr: 4.0000e-05
# Epoch 22/50
# 215/215 [==============================] - 5s 23ms/step - loss: 1.7662 - accuracy: 0.2747 - val_loss: 1.7673 - val_accuracy: 0.2707 - lr: 4.0000e-05
# Epoch 23/50
# 215/215 [==============================] - 5s 23ms/step - loss: 1.7664 - accuracy: 0.2741 - val_loss: 1.7738 - val_accuracy: 0.2728 - lr: 4.0000e-05
# Epoch 24/50
# 214/215 [============================>.] - ETA: 0s - loss: 1.7658 - accuracy: 0.2749
# Epoch 24: ReduceLROnPlateau reducing learning rate to 1e-05.
# 215/215 [==============================] - 5s 24ms/step - loss: 1.7657 - accuracy: 0.2749 - val_loss: 1.7748 - val_accuracy: 0.2728 - lr: 4.0000e-05
# Epoch 25/50
# 215/215 [==============================] - 5s 23ms/step - loss: 1.7641 - accuracy: 0.2736 - val_loss: 1.7693 - val_accuracy: 0.2717 - lr: 1.0000e-05
# Epoch 26/50
# 215/215 [==============================] - 5s 24ms/step - loss: 1.7649 - accuracy: 0.2717 - val_loss: 1.7687 - val_accuracy: 0.2678 - lr: 1.0000e-05
# Epoch 27/50
# 215/215 [==============================] - 5s 24ms/step - loss: 1.7660 - accuracy: 0.2707 - val_loss: 1.7754 - val_accuracy: 0.2739 - lr: 1.0000e-05
# Epoch 28/50
# 215/215 [==============================] - 5s 23ms/step - loss: 1.7654 - accuracy: 0.2722 - val_loss: 1.7684 - val_accuracy: 0.2793 - lr: 1.0000e-05
# Epoch 29/50
# 215/215 [==============================] - 5s 23ms/step - loss: 1.7650 - accuracy: 0.2735 - val_loss: 1.7726 - val_accuracy: 0.2649 - lr: 1.0000e-05
# Epoch 30/50
# 215/215 [==============================] - 5s 23ms/step - loss: 1.7662 - accuracy: 0.2713 - val_loss: 1.7666 - val_accuracy: 0.2764 - lr: 1.0000e-05
# Epoch 31/50
# 215/215 [==============================] - 5s 23ms/step - loss: 1.7652 - accuracy: 0.2713 - val_loss: 1.7727 - val_accuracy: 0.2620 - lr: 1.0000e-05
# Epoch 32/50
# 215/215 [==============================] - 5s 23ms/step - loss: 1.7652 - accuracy: 0.2712 - val_loss: 1.7765 - val_accuracy: 0.2779 - lr: 1.0000e-05
# Epoch 33/50
# 215/215 [==============================] - 5s 23ms/step - loss: 1.7658 - accuracy: 0.2744 - val_loss: 1.7636 - val_accuracy: 0.2746 - lr: 1.0000e-05
# Epoch 34/50
# 215/215 [==============================] - 5s 23ms/step - loss: 1.7647 - accuracy: 0.2724 - val_loss: 1.7745 - val_accuracy: 0.2659 - lr: 1.0000e-05
# Epoch 35/50
# 215/215 [==============================] - 5s 24ms/step - loss: 1.7648 - accuracy: 0.2747 - val_loss: 1.7692 - val_accuracy: 0.2750 - lr: 1.0000e-05
# Epoch 36/50
# 215/215 [==============================] - 5s 24ms/step - loss: 1.7646 - accuracy: 0.2726 - val_loss: 1.7682 - val_accuracy: 0.2710 - lr: 1.0000e-05
# Epoch 37/50
# 215/215 [==============================] - 7s 30ms/step - loss: 1.7640 - accuracy: 0.2739 - val_loss: 1.7725 - val_accuracy: 0.2804 - lr: 1.0000e-05
# Epoch 38/50
# 215/215 [==============================] - 5s 23ms/step - loss: 1.7656 - accuracy: 0.2722 - val_loss: 1.7814 - val_accuracy: 0.2667 - lr: 1.0000e-05
# Epoch 39/50
# 215/215 [==============================] - 5s 23ms/step - loss: 1.7632 - accuracy: 0.2736 - val_loss: 1.7681 - val_accuracy: 0.2707 - lr: 1.0000e-05
# Epoch 40/50
# 215/215 [==============================] - 5s 23ms/step - loss: 1.7666 - accuracy: 0.2735 - val_loss: 1.7729 - val_accuracy: 0.2674 - lr: 1.0000e-05
# Epoch 41/50
# 215/215 [==============================] - 5s 23ms/step - loss: 1.7643 - accuracy: 0.2738 - val_loss: 1.7691 - val_accuracy: 0.2779 - lr: 1.0000e-05
# Epoch 42/50
# 215/215 [==============================] - 5s 23ms/step - loss: 1.7648 - accuracy: 0.2740 - val_loss: 1.7739 - val_accuracy: 0.2649 - lr: 1.0000e-05
# Epoch 43/50
# 215/215 [==============================] - 5s 23ms/step - loss: 1.7652 - accuracy: 0.2717 - val_loss: 1.7680 - val_accuracy: 0.2797 - lr: 1.0000e-05
# Epoch 44/50
# 215/215 [==============================] - 5s 23ms/step - loss: 1.7653 - accuracy: 0.2721 - val_loss: 1.7746 - val_accuracy: 0.2703 - lr: 1.0000e-05
# Epoch 45/50
# 215/215 [==============================] - 5s 23ms/step - loss: 1.7644 - accuracy: 0.2741 - val_loss: 1.7684 - val_accuracy: 0.2714 - lr: 1.0000e-05
# Epoch 46/50
# 215/215 [==============================] - 5s 23ms/step - loss: 1.7652 - accuracy: 0.2729 - val_loss: 1.7688 - val_accuracy: 0.2725 - lr: 1.0000e-05
# Epoch 47/50
# 215/215 [==============================] - ETA: 0s - loss: 1.7655 - accuracy: 0.2735Restoring model weights from the end of the best epoch: 37.
# 215/215 [==============================] - 5s 23ms/step - loss: 1.7655 - accuracy: 0.2735 - val_loss: 1.7645 - val_accuracy: 0.2721 - lr: 1.0000e-05
# Epoch 47: early stopping

# %%
# Plot the loss and accuracy curves for training and validation 
fig, ax = plt.subplots(2,1, figsize=(18, 10))
ax[0].plot(history.history['loss'], color='b', label="Training loss")
ax[0].plot(history.history['val_loss'], color='r', label="validation loss",axes =ax[0])
legend = ax[0].legend(loc='best', shadow=True)

ax[1].plot(history.history['accuracy'], color='b', label="Training accuracy")
ax[1].plot(history.history['val_accuracy'], color='r',label="Validation accuracy")
legend = ax[1].legend(loc='best', shadow=True)

# %%
fig = plt.figure(figsize=(14, 18)) # Set Figure

y_pred = model.predict(X_test) # Predict class probabilities as 2 => [0.1, 0, 0.9, 0, 0, 0, 0, 0, 0, 0]

Y_pred = np.argmax(y_pred, 1) # Decode Predicted labels
Y_test = np.argmax(y_test, 1) # Decode labels
print(y_test.shape)

mat = confusion_matrix(Y_test, Y_pred) # Confusion matrix

#Plot Confusion matrix
sns.heatmap(mat.T, square=True, annot=True, cbar=False, cmap=plt.cm.Blues, fmt='.0f')
plt.xlabel('Predicted Values')
plt.ylabel('True Values');
plt.show();
# Out:
# 90/90 [==============================] - 0s 1ms/step
# (2871, 7)

# %%
y_pred = model.predict(X_test)
X_test__ = X_test.reshape(X_test.shape[0], 8, 8)

fig, axis = plt.subplots(4, 4, figsize=(12, 12))
fig.tight_layout(pad=3.0)
for i, ax in enumerate(axis.flat):
    ax.imshow(X_test__[i], cmap='binary')
    ax.set(title = f"Real emotion class {emotions[y_test[i].argmax()]}\nPredicted emotion class {emotions[y_pred[i].argmax()]}");
# Out:
# 90/90 [==============================] - 0s 1ms/step
