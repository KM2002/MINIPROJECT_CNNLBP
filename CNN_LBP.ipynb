# %%
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dense, Dropout, Lambda, Flatten, Conv2D, BatchNormalization, Activation, MaxPooling2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.datasets import mnist
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import seaborn as sns
import numpy as np
import pandas as pd
import PIL
from PIL import Image
import cv2
import os
import matplotlib.pyplot as plt
# Out:
# 2023-04-08 15:24:56.467508: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
train=pd.read_csv('/Users/khushm/Documents/GitHub/MINIPROJECT_CNNLBP/training_cnn.csv')
test=pd.read_csv('/Users/khushm/Documents/GitHub/MINIPROJECT_CNNLBP/testing_cnn.csv')
sub=pd.read_csv('/Users/khushm/Documents/GitHub/MINIPROJECT_CNNLBP/output.csv')
emotions = ('happy', 'sad','fearful','neutral','angry','disgusted','surprised')

# %%
print(f"Training data size {train.shape}\nTesting data size {test.shape}")
# Out:
# Training data size (28709, 2305)
# Testing data size (7178, 2304)

# %%
X = train.drop(['Labels'], 1).values
y = train['Labels'].values
X = X / 255.0
#reshaping the image to 3 dimensions, canal=1 for grayscale
X = X.reshape(-1,48,48,1) 
#Encoding labels to one hot vector 
y = to_categorical(y) 
print(f"Label size {y.shape}")
# Out:
# /var/folders/m5/g2s2vm2d69s8qfj5cc66mryw0000gn/T/ipykernel_2847/1925213489.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   X = train.drop(['Labels'], 1).values
# Label size (28709, 7)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=0)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((25838, 48, 48, 1), (2871, 48, 48, 1), (25838, 7), (2871, 7))

# %%
X_train__ = X_train.reshape(X_train.shape[0], 48, 48)
fig, axis = plt.subplots(1, 4, figsize=(20, 10))
for i, ax in enumerate(axis.flat):
    ax.imshow(X_train__[i], cmap='binary')
    digit = y_train[i].argmax()
    ax.set(title = f"Real emotion is {emotions[digit]}"); #Data visualisation

# %%
mean = np.mean(X_train)
std = np.std(X_train)

def standardize(x):
    return (x-mean)/std #Normalisation

# %%
#Defining the CNN model

model=Sequential()
   
model.add(Conv2D(filters=64, kernel_size = (3,3), activation="relu", input_shape=(48,48,1)))
model.add(Conv2D(filters=64, kernel_size = (3,3), activation="relu"))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())

model.add(Conv2D(filters=128, kernel_size = (3,3), activation="relu"))
model.add(Conv2D(filters=128, kernel_size = (3,3), activation="relu"))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())    

model.add(Conv2D(filters=256, kernel_size = (3,3), activation="relu"))
model.add(Conv2D(filters=256, kernel_size = (3,3), activation="relu"))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())
    
model.add(Flatten())
model.add(Dense(512,activation="relu"))
    
model.add(Dense(7,activation="softmax"))
    
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 46, 46, 64)        640
#
#  conv2d_1 (Conv2D)           (None, 44, 44, 64)        36928
#
#  max_pooling2d (MaxPooling2D  (None, 22, 22, 64)       0
#  )
#
#  batch_normalization (BatchN  (None, 22, 22, 64)       256
#  ormalization)
#
#  conv2d_2 (Conv2D)           (None, 20, 20, 128)       73856
#
#  conv2d_3 (Conv2D)           (None, 18, 18, 128)       147584
#
#  max_pooling2d_1 (MaxPooling  (None, 9, 9, 128)        0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 9, 9, 128)        512
#  hNormalization)
#
#  conv2d_4 (Conv2D)           (None, 7, 7, 256)         295168
#
#  conv2d_5 (Conv2D)           (None, 5, 5, 256)         590080
#
#  max_pooling2d_2 (MaxPooling  (None, 2, 2, 256)        0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 2, 2, 256)        1024
#  hNormalization)
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 512)               524800
#
#  dense_1 (Dense)             (None, 7)                 3591
#
# =================================================================
# Total params: 1,674,439
# Trainable params: 1,673,543
# Non-trainable params: 896
# _________________________________________________________________
# 2023-04-08 15:25:25.379188: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# With data augmentation to prevent overfitting

datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=15,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.01, # Randomly zoom image 
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=False,  # randomly flip images
        vertical_flip=False)  # randomly flip images


#datagen.fit(X_train)
train_gen = datagen.flow(X_train, y_train, batch_size=120)
test_gen = datagen.flow(X_test, y_test, batch_size=120)

# %%
epochs = 50
batch_size = 120
train_steps = X_train.shape[0] // batch_size
valid_steps = X_test.shape[0] // batch_size

es = tf.keras.callbacks.EarlyStopping(
        monitor="val_accuracy", # metrics to monitor
        patience=10, # how many epochs before stop
        verbose=1,
        mode="max", # we need the maximum accuracy.
        restore_best_weights=True, # 
     )

rp = tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_accuracy",
        factor=0.2,
        patience=3,
        verbose=1,
        mode="max",
        min_lr=0.00001,
     )

# %%
# Fit the model
history = model.fit(train_gen, 
                              epochs = epochs, 
                              steps_per_epoch = train_steps,
                              validation_data = test_gen,
                              validation_steps = valid_steps, 
                              callbacks=[es, rp])
# Out:
# Epoch 1/50
# 215/215 [==============================] - 472s 2s/step - loss: 1.7790 - accuracy: 0.3239 - val_loss: 2.3892 - val_accuracy: 0.1609 - lr: 0.0010
# Epoch 2/50
# 215/215 [==============================] - 449s 2s/step - loss: 1.4886 - accuracy: 0.4231 - val_loss: 2.0479 - val_accuracy: 0.1337 - lr: 0.0010
# Epoch 3/50
# 215/215 [==============================] - 428s 2s/step - loss: 1.3859 - accuracy: 0.4717 - val_loss: 1.7154 - val_accuracy: 0.3935 - lr: 0.0010
# Epoch 4/50
# 215/215 [==============================] - 447s 2s/step - loss: 1.3179 - accuracy: 0.4959 - val_loss: 1.4871 - val_accuracy: 0.4333 - lr: 0.0010
# Epoch 5/50
# 215/215 [==============================] - 471s 2s/step - loss: 1.2678 - accuracy: 0.5156 - val_loss: 1.3104 - val_accuracy: 0.5033 - lr: 0.0010
# Epoch 6/50
# 215/215 [==============================] - 461s 2s/step - loss: 1.2270 - accuracy: 0.5312 - val_loss: 1.3103 - val_accuracy: 0.5152 - lr: 0.0010
# Epoch 7/50
# 215/215 [==============================] - 446s 2s/step - loss: 1.2043 - accuracy: 0.5402 - val_loss: 1.2693 - val_accuracy: 0.5210 - lr: 0.0010
# Epoch 8/50
# 215/215 [==============================] - 427s 2s/step - loss: 1.1713 - accuracy: 0.5546 - val_loss: 1.2770 - val_accuracy: 0.5120 - lr: 0.0010
# Epoch 9/50
# 215/215 [==============================] - 428s 2s/step - loss: 1.1498 - accuracy: 0.5600 - val_loss: 1.2664 - val_accuracy: 0.5286 - lr: 0.0010
# Epoch 10/50
# 215/215 [==============================] - 428s 2s/step - loss: 1.1184 - accuracy: 0.5761 - val_loss: 1.2514 - val_accuracy: 0.5319 - lr: 0.0010
# Epoch 11/50
# 215/215 [==============================] - 429s 2s/step - loss: 1.1016 - accuracy: 0.5815 - val_loss: 1.2679 - val_accuracy: 0.5341 - lr: 0.0010
# Epoch 12/50
# 215/215 [==============================] - 426s 2s/step - loss: 1.0786 - accuracy: 0.5857 - val_loss: 1.2399 - val_accuracy: 0.5435 - lr: 0.0010
# Epoch 13/50
# 215/215 [==============================] - 427s 2s/step - loss: 1.0489 - accuracy: 0.5999 - val_loss: 1.3085 - val_accuracy: 0.5254 - lr: 0.0010
# Epoch 14/50
# 215/215 [==============================] - 427s 2s/step - loss: 1.0292 - accuracy: 0.6102 - val_loss: 1.5778 - val_accuracy: 0.4707 - lr: 0.0010
# Epoch 15/50
# 215/215 [==============================] - ETA: 0s - loss: 1.0060 - accuracy: 0.6187
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 215/215 [==============================] - 428s 2s/step - loss: 1.0060 - accuracy: 0.6187 - val_loss: 1.8592 - val_accuracy: 0.4993 - lr: 0.0010
# Epoch 16/50
# 215/215 [==============================] - 426s 2s/step - loss: 0.9003 - accuracy: 0.6625 - val_loss: 1.1403 - val_accuracy: 0.5768 - lr: 2.0000e-04
# Epoch 17/50
# 215/215 [==============================] - 429s 2s/step - loss: 0.8537 - accuracy: 0.6771 - val_loss: 1.1448 - val_accuracy: 0.5899 - lr: 2.0000e-04
# Epoch 18/50
# 215/215 [==============================] - 427s 2s/step - loss: 0.8258 - accuracy: 0.6892 - val_loss: 1.1420 - val_accuracy: 0.5917 - lr: 2.0000e-04
# Epoch 19/50
# 215/215 [==============================] - 429s 2s/step - loss: 0.8001 - accuracy: 0.6989 - val_loss: 1.1527 - val_accuracy: 0.5917 - lr: 2.0000e-04
# Epoch 20/50
# 215/215 [==============================] - 432s 2s/step - loss: 0.7796 - accuracy: 0.7062 - val_loss: 1.1711 - val_accuracy: 0.5873 - lr: 2.0000e-04
# Epoch 21/50
# 215/215 [==============================] - ETA: 0s - loss: 0.7561 - accuracy: 0.7169
# Epoch 21: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 215/215 [==============================] - 442s 2s/step - loss: 0.7561 - accuracy: 0.7169 - val_loss: 1.1745 - val_accuracy: 0.5891 - lr: 2.0000e-04
# Epoch 22/50
# 215/215 [==============================] - 459s 2s/step - loss: 0.7206 - accuracy: 0.7295 - val_loss: 1.1782 - val_accuracy: 0.5906 - lr: 4.0000e-05
# Epoch 23/50
# 215/215 [==============================] - 451s 2s/step - loss: 0.7057 - accuracy: 0.7368 - val_loss: 1.1824 - val_accuracy: 0.5938 - lr: 4.0000e-05
# Epoch 24/50
# 215/215 [==============================] - 492s 2s/step - loss: 0.6990 - accuracy: 0.7385 - val_loss: 1.1568 - val_accuracy: 0.5946 - lr: 4.0000e-05
# Epoch 25/50
# 215/215 [==============================] - 500s 2s/step - loss: 0.6945 - accuracy: 0.7393 - val_loss: 1.1775 - val_accuracy: 0.5884 - lr: 4.0000e-05
# Epoch 26/50
# 215/215 [==============================] - 514s 2s/step - loss: 0.6867 - accuracy: 0.7449 - val_loss: 1.1791 - val_accuracy: 0.5971 - lr: 4.0000e-05
# Epoch 27/50
# 215/215 [==============================] - 519s 2s/step - loss: 0.6824 - accuracy: 0.7455 - val_loss: 1.1973 - val_accuracy: 0.5877 - lr: 4.0000e-05
# Epoch 28/50
# 215/215 [==============================] - 512s 2s/step - loss: 0.6796 - accuracy: 0.7450 - val_loss: 1.2149 - val_accuracy: 0.5859 - lr: 4.0000e-05
# Epoch 29/50
# 215/215 [==============================] - ETA: 0s - loss: 0.6720 - accuracy: 0.7498
# Epoch 29: ReduceLROnPlateau reducing learning rate to 1e-05.
# 215/215 [==============================] - 483s 2s/step - loss: 0.6720 - accuracy: 0.7498 - val_loss: 1.1964 - val_accuracy: 0.5942 - lr: 4.0000e-05
# Epoch 30/50
# 215/215 [==============================] - 533s 2s/step - loss: 0.6655 - accuracy: 0.7524 - val_loss: 1.1593 - val_accuracy: 0.6014 - lr: 1.0000e-05
# Epoch 31/50
# 215/215 [==============================] - 490s 2s/step - loss: 0.6619 - accuracy: 0.7545 - val_loss: 1.1678 - val_accuracy: 0.6007 - lr: 1.0000e-05
# Epoch 32/50
# 215/215 [==============================] - 505s 2s/step - loss: 0.6635 - accuracy: 0.7531 - val_loss: 1.1998 - val_accuracy: 0.6007 - lr: 1.0000e-05
# Epoch 33/50
# 215/215 [==============================] - 511s 2s/step - loss: 0.6620 - accuracy: 0.7535 - val_loss: 1.1751 - val_accuracy: 0.6025 - lr: 1.0000e-05
# Epoch 34/50
# 215/215 [==============================] - 520s 2s/step - loss: 0.6530 - accuracy: 0.7571 - val_loss: 1.1955 - val_accuracy: 0.5833 - lr: 1.0000e-05
# Epoch 35/50
# 215/215 [==============================] - 546s 3s/step - loss: 0.6560 - accuracy: 0.7545 - val_loss: 1.2060 - val_accuracy: 0.5920 - lr: 1.0000e-05
# Epoch 36/50
# 215/215 [==============================] - 518s 2s/step - loss: 0.6573 - accuracy: 0.7564 - val_loss: 1.2122 - val_accuracy: 0.5928 - lr: 1.0000e-05
# Epoch 37/50
# 215/215 [==============================] - 460s 2s/step - loss: 0.6547 - accuracy: 0.7566 - val_loss: 1.2025 - val_accuracy: 0.5978 - lr: 1.0000e-05
# Epoch 38/50
# 215/215 [==============================] - 429s 2s/step - loss: 0.6537 - accuracy: 0.7585 - val_loss: 1.1830 - val_accuracy: 0.6000 - lr: 1.0000e-05
# Epoch 39/50
# 215/215 [==============================] - 433s 2s/step - loss: 0.6480 - accuracy: 0.7585 - val_loss: 1.2020 - val_accuracy: 0.5913 - lr: 1.0000e-05
# Epoch 40/50
# 215/215 [==============================] - 545s 3s/step - loss: 0.6496 - accuracy: 0.7575 - val_loss: 1.1798 - val_accuracy: 0.5967 - lr: 1.0000e-05
# Epoch 41/50
# 215/215 [==============================] - 531s 2s/step - loss: 0.6498 - accuracy: 0.7589 - val_loss: 1.2059 - val_accuracy: 0.5946 - lr: 1.0000e-05
# Epoch 42/50
# 215/215 [==============================] - 480s 2s/step - loss: 0.6395 - accuracy: 0.7611 - val_loss: 1.2188 - val_accuracy: 0.5909 - lr: 1.0000e-05
# Epoch 43/50
# 215/215 [==============================] - ETA: 0s - loss: 0.6419 - accuracy: 0.7617Restoring model weights from the end of the best epoch: 33.
# 215/215 [==============================] - 547s 3s/step - loss: 0.6419 - accuracy: 0.7617 - val_loss: 1.2112 - val_accuracy: 0.5866 - lr: 1.0000e-05
# Epoch 43: early stopping

# %%
# Plot the loss and accuracy curves for training and validation 
fig, ax = plt.subplots(2,1, figsize=(18, 10))
ax[0].plot(history.history['loss'], color='b', label="Training loss")
ax[0].plot(history.history['val_loss'], color='r', label="validation loss",axes =ax[0])
legend = ax[0].legend(loc='best', shadow=True)

ax[1].plot(history.history['accuracy'], color='b', label="Training accuracy")
ax[1].plot(history.history['val_accuracy'], color='r',label="Validation accuracy")
legend = ax[1].legend(loc='best', shadow=True)

# %%
fig = plt.figure(figsize=(14, 18)) # Set Figure

y_pred = model.predict(X_test) # Predict class probabilities as 2 => [0.1, 0, 0.9, 0, 0, 0, 0, 0, 0, 0]

Y_pred = np.argmax(y_pred, 1) # Decode Predicted labels
Y_test = np.argmax(y_test, 1) # Decode labels
print(y_test.shape)

mat = confusion_matrix(Y_test, Y_pred) # Confusion matrix

#Plot Confusion matrix
sns.heatmap(mat.T, square=True, annot=True, cbar=False, cmap=plt.cm.Blues, fmt='.0f')
plt.xlabel('Predicted Values')
plt.ylabel('True Values');
plt.show();
# Out:
# 90/90 [==============================] - 15s 168ms/step
# (2871, 7)

# %%
y_pred = model.predict(X_test)
X_test__ = X_test.reshape(X_test.shape[0], 48, 48)

fig, axis = plt.subplots(4, 4, figsize=(12, 14))
fig.tight_layout(pad=3.0)
for i, ax in enumerate(axis.flat):
    ax.imshow(X_test__[i], cmap='binary')
    ax.set(title = f"Real emotion class {emotions[y_test[i].argmax()]}\nPredicted emotion class {emotions[y_pred[i].argmax()]}");
# Out:
# 90/90 [==============================] - 15s 168ms/step
