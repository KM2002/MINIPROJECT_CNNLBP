# %%
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dense, Dropout, Lambda, Flatten, Conv2D, BatchNormalization, Activation, MaxPooling2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.datasets import mnist
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import seaborn as sns
import numpy as np
import pandas as pd
import PIL
from PIL import Image
import cv2
import os
import matplotlib.pyplot as plt
# Out:
# 2023-04-04 13:46:06.608213: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
train=pd.read_csv('/Users/sneha/Desktop/MINIPROJECT_CNNLBP/train.csv')
test=pd.read_csv('/Users/sneha/Desktop/MINIPROJECT_CNNLBP/test.csv')
sub=pd.read_csv('/Users/sneha/Desktop/MINIPROJECT_CNNLBP/output.csv')
emotions = ('happy', 'sad','fearful','neutral','angry','disgusted','surprised')

# %%
print(f"Training data size {train.shape}\nTesting data size {test.shape}")
# Out:
# Training data size (28709, 2305)
# Testing data size (7178, 2304)

# %%
X = train.drop(['Labels'], axis=1).values
y = train['Labels'].values
X = X / 255.0
X = X.reshape(-1,48,48,1) #reshaping the image to 3 dimensions, canal=1 for grayscale
y = to_categorical(y) #Encoding labels to one hot vector 
print(f"Label size {y.shape}")
# Out:
# Label size (28709, 7)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=0)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((25838, 48, 48, 1), (2871, 48, 48, 1), (25838, 7), (2871, 7))

# %%
X_train__ = X_train.reshape(X_train.shape[0], 48, 48)
fig, axis = plt.subplots(1, 4, figsize=(20, 10))
for i, ax in enumerate(axis.flat):
    ax.imshow(X_train__[i], cmap='binary')
    digit = y_train[i].argmax()
    ax.set(title = f"Real emotion is {emotions[digit]}"); #Data visualisation

# %%
mean = np.mean(X_train)
std = np.std(X_train)

def standardize(x):
    return (x-mean)/std #Normalisation

# %%
#Defining the CNN model

model=Sequential()
   
model.add(Conv2D(filters=64, kernel_size = (3,3), activation="relu", input_shape=(48,48,1)))
model.add(Conv2D(filters=64, kernel_size = (3,3), activation="relu"))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())

model.add(Conv2D(filters=128, kernel_size = (3,3), activation="relu"))
model.add(Conv2D(filters=128, kernel_size = (3,3), activation="relu"))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())    

model.add(Conv2D(filters=256, kernel_size = (3,3), activation="relu"))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())
    
model.add(Flatten())
model.add(Dense(512,activation="relu"))
    
model.add(Dense(7,activation="softmax"))
    
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
# Out:
# 2023-04-04 13:46:19.425402: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# With data augmentation to prevent overfitting

datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=15,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.01, # Randomly zoom image 
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=False,  # randomly flip images
        vertical_flip=False)  # randomly flip images


#datagen.fit(X_train)
train_gen = datagen.flow(X_train, y_train, batch_size=120)
test_gen = datagen.flow(X_test, y_test, batch_size=120)

# %%
epochs = 50
batch_size = 120
train_steps = X_train.shape[0] // batch_size
valid_steps = X_test.shape[0] // batch_size

es = tf.keras.callbacks.EarlyStopping(
        monitor="val_accuracy", # metrics to monitor
        patience=10, # how many epochs before stop
        verbose=1,
        mode="max", # we need the maximum accuracy.
        restore_best_weights=True, # 
     )

rp = tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_accuracy",
        factor=0.2,
        patience=3,
        verbose=1,
        mode="max",
        min_lr=0.00001,
     )

# %%
# Fit the model
history = model.fit(train_gen, 
                              epochs = epochs, 
                              steps_per_epoch = train_steps,
                              validation_data = test_gen,
                              validation_steps = valid_steps, 
                              callbacks=[es, rp])
# Out:
# Epoch 1/50
# 215/215 [==============================] - 213s 985ms/step - loss: 2.0581 - accuracy: 0.2686 - val_loss: 2.0226 - val_accuracy: 0.2906 - lr: 0.0010
# Epoch 2/50
# 215/215 [==============================] - 224s 1s/step - loss: 1.5985 - accuracy: 0.3933 - val_loss: 2.1250 - val_accuracy: 0.2087 - lr: 0.0010
# Epoch 3/50
# 215/215 [==============================] - 228s 1s/step - loss: 1.3899 - accuracy: 0.4685 - val_loss: 1.7282 - val_accuracy: 0.2841 - lr: 0.0010
# Epoch 4/50
# 215/215 [==============================] - 230s 1s/step - loss: 1.2836 - accuracy: 0.5121 - val_loss: 1.6688 - val_accuracy: 0.2993 - lr: 0.0010
# Epoch 5/50
# 215/215 [==============================] - 231s 1s/step - loss: 1.2128 - accuracy: 0.5383 - val_loss: 1.4666 - val_accuracy: 0.4170 - lr: 0.0010
# Epoch 6/50
# 215/215 [==============================] - 238s 1s/step - loss: 1.1555 - accuracy: 0.5617 - val_loss: 1.5563 - val_accuracy: 0.4402 - lr: 0.0010
# Epoch 7/50
# 215/215 [==============================] - 240s 1s/step - loss: 1.1198 - accuracy: 0.5781 - val_loss: 1.5121 - val_accuracy: 0.4460 - lr: 0.0010
# Epoch 8/50
# 215/215 [==============================] - 240s 1s/step - loss: 1.0740 - accuracy: 0.5967 - val_loss: 1.2386 - val_accuracy: 0.5402 - lr: 0.0010
# Epoch 9/50
# 215/215 [==============================] - 240s 1s/step - loss: 1.0466 - accuracy: 0.6052 - val_loss: 1.1607 - val_accuracy: 0.5696 - lr: 0.0010
# Epoch 10/50
# 215/215 [==============================] - 240s 1s/step - loss: 1.0083 - accuracy: 0.6230 - val_loss: 1.2045 - val_accuracy: 0.5543 - lr: 0.0010
# Epoch 11/50
# 215/215 [==============================] - 241s 1s/step - loss: 0.9850 - accuracy: 0.6277 - val_loss: 1.3042 - val_accuracy: 0.5196 - lr: 0.0010
# Epoch 12/50
# 215/215 [==============================] - 241s 1s/step - loss: 0.9470 - accuracy: 0.6448 - val_loss: 1.1510 - val_accuracy: 0.5746 - lr: 0.0010
# Epoch 13/50
# 215/215 [==============================] - 241s 1s/step - loss: 0.9216 - accuracy: 0.6551 - val_loss: 1.2023 - val_accuracy: 0.5601 - lr: 0.0010
# Epoch 14/50
# 215/215 [==============================] - 242s 1s/step - loss: 0.8965 - accuracy: 0.6646 - val_loss: 1.1582 - val_accuracy: 0.5663 - lr: 0.0010
# Epoch 15/50
# 215/215 [==============================] - 241s 1s/step - loss: 0.8671 - accuracy: 0.6760 - val_loss: 1.1628 - val_accuracy: 0.5790 - lr: 0.0010
# Epoch 16/50
# 215/215 [==============================] - 241s 1s/step - loss: 0.8416 - accuracy: 0.6863 - val_loss: 1.2955 - val_accuracy: 0.5442 - lr: 0.0010
# Epoch 17/50
# 215/215 [==============================] - 245s 1s/step - loss: 0.8152 - accuracy: 0.6976 - val_loss: 1.1942 - val_accuracy: 0.5826 - lr: 0.0010
# Epoch 18/50
# 215/215 [==============================] - 248s 1s/step - loss: 0.7924 - accuracy: 0.7079 - val_loss: 1.2028 - val_accuracy: 0.5891 - lr: 0.0010
# Epoch 19/50
# 215/215 [==============================] - 247s 1s/step - loss: 0.7607 - accuracy: 0.7202 - val_loss: 1.3078 - val_accuracy: 0.5493 - lr: 0.0010
# Epoch 20/50
# 215/215 [==============================] - 246s 1s/step - loss: 0.7444 - accuracy: 0.7251 - val_loss: 1.1960 - val_accuracy: 0.5779 - lr: 0.0010
# Epoch 21/50
# 215/215 [==============================] - ETA: 0s - loss: 0.7239 - accuracy: 0.7323
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 215/215 [==============================] - 249s 1s/step - loss: 0.7239 - accuracy: 0.7323 - val_loss: 1.3230 - val_accuracy: 0.5754 - lr: 0.0010
# Epoch 22/50
# 215/215 [==============================] - 248s 1s/step - loss: 0.6204 - accuracy: 0.7697 - val_loss: 1.1375 - val_accuracy: 0.6076 - lr: 2.0000e-04
# Epoch 23/50
# 215/215 [==============================] - 248s 1s/step - loss: 0.5620 - accuracy: 0.7956 - val_loss: 1.1431 - val_accuracy: 0.6199 - lr: 2.0000e-04
# Epoch 24/50
# 215/215 [==============================] - 247s 1s/step - loss: 0.5432 - accuracy: 0.8029 - val_loss: 1.1888 - val_accuracy: 0.6159 - lr: 2.0000e-04
# Epoch 25/50
# 215/215 [==============================] - 247s 1s/step - loss: 0.5152 - accuracy: 0.8139 - val_loss: 1.1575 - val_accuracy: 0.6333 - lr: 2.0000e-04
# Epoch 26/50
# 215/215 [==============================] - 247s 1s/step - loss: 0.5018 - accuracy: 0.8193 - val_loss: 1.1627 - val_accuracy: 0.6264 - lr: 2.0000e-04
# Epoch 27/50
# 215/215 [==============================] - 248s 1s/step - loss: 0.4835 - accuracy: 0.8261 - val_loss: 1.1743 - val_accuracy: 0.6225 - lr: 2.0000e-04
# Epoch 28/50
# 215/215 [==============================] - ETA: 0s - loss: 0.4728 - accuracy: 0.8333
# Epoch 28: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 215/215 [==============================] - 246s 1s/step - loss: 0.4728 - accuracy: 0.8333 - val_loss: 1.1578 - val_accuracy: 0.6246 - lr: 2.0000e-04
# Epoch 29/50
# 215/215 [==============================] - 245s 1s/step - loss: 0.4468 - accuracy: 0.8417 - val_loss: 1.1571 - val_accuracy: 0.6312 - lr: 4.0000e-05
# Epoch 30/50
# 215/215 [==============================] - 244s 1s/step - loss: 0.4268 - accuracy: 0.8456 - val_loss: 1.1663 - val_accuracy: 0.6290 - lr: 4.0000e-05
# Epoch 31/50
# 215/215 [==============================] - ETA: 0s - loss: 0.4304 - accuracy: 0.8484
# Epoch 31: ReduceLROnPlateau reducing learning rate to 1e-05.
# 215/215 [==============================] - 247s 1s/step - loss: 0.4304 - accuracy: 0.8484 - val_loss: 1.1895 - val_accuracy: 0.6297 - lr: 4.0000e-05
# Epoch 32/50
# 215/215 [==============================] - 246s 1s/step - loss: 0.4233 - accuracy: 0.8483 - val_loss: 1.1661 - val_accuracy: 0.6254 - lr: 1.0000e-05
# Epoch 33/50
# 215/215 [==============================] - 246s 1s/step - loss: 0.4234 - accuracy: 0.8490 - val_loss: 1.1598 - val_accuracy: 0.6308 - lr: 1.0000e-05
# Epoch 34/50
# 215/215 [==============================] - 245s 1s/step - loss: 0.4191 - accuracy: 0.8510 - val_loss: 1.1761 - val_accuracy: 0.6315 - lr: 1.0000e-05
# Epoch 35/50
# 215/215 [==============================] - ETA: 0s - loss: 0.4203 - accuracy: 0.8492Restoring model weights from the end of the best epoch: 25.
# 215/215 [==============================] - 246s 1s/step - loss: 0.4203 - accuracy: 0.8492 - val_loss: 1.1856 - val_accuracy: 0.6308 - lr: 1.0000e-05
# Epoch 35: early stopping

# %%
# Plot the loss and accuracy curves for training and validation 
fig, ax = plt.subplots(2,1, figsize=(18, 10))
ax[0].plot(history.history['loss'], color='b', label="Training loss")
ax[0].plot(history.history['val_loss'], color='r', label="validation loss",axes =ax[0])
legend = ax[0].legend(loc='best', shadow=True)

ax[1].plot(history.history['accuracy'], color='b', label="Training accuracy")
ax[1].plot(history.history['val_accuracy'], color='r',label="Validation accuracy")
legend = ax[1].legend(loc='best', shadow=True)

# %%
fig = plt.figure(figsize=(14, 18)) # Set Figure

y_pred = model.predict(X_test) # Predict class probabilities as 2 => [0.1, 0, 0.9, 0, 0, 0, 0, 0, 0, 0]

Y_pred = np.argmax(y_pred, 1) # Decode Predicted labels
Y_test = np.argmax(y_test, 1) # Decode labels
print(y_test.shape)

mat = confusion_matrix(Y_test, Y_pred) # Confusion matrix

#Plot Confusion matrix
sns.heatmap(mat.T, square=True, annot=True, cbar=False, cmap=plt.cm.Blues, fmt='.0f')
plt.xlabel('Predicted Values')
plt.ylabel('True Values');
plt.show();
# Out:
# 90/90 [==============================] - 9s 97ms/step
# (2871, 7)

# %%
y_pred = model.predict(X_test)
X_test__ = X_test.reshape(X_test.shape[0], 48, 48)

fig, axis = plt.subplots(4, 4, figsize=(12, 14))
fig.tight_layout(pad=3.0)
for i, ax in enumerate(axis.flat):
    ax.imshow(X_test__[i], cmap='binary')
    ax.set(title = f"Real emotion class {emotions[y_test[i].argmax()]}\nPredicted emotion class {emotions[y_pred[i].argmax()]}");
# Out:
# 90/90 [==============================] - 7s 79ms/step
